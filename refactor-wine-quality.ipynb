# %% [markdown]
# # Refactor: Wine Quality Analysis
# In this exercise, you'll refactor code that analyzes a wine quality dataset taken from the UCI Machine Learning Repository [here](https://archive.ics.uci.edu/ml/datasets/wine+quality). Each row contains data on a wine sample, including several physicochemical properties gathered from tests, as well as a quality rating evaluated by wine experts.
#
# The code in this notebook first renames the columns of the dataset and then calculates some statistics on how some features may be related to quality ratings. Can you refactor this code to make it more clean and modular?

# %%
import pandas as pd
dataset = pd.read_csv('winequality-red.csv', sep=';')
dataset.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %% [markdown]
# ### Renaming Columns
# You want to replace the spaces in the column labels with underscores to be able to reference columns with dot notation. Here's one way you could've done it.

# %%
dataset_underscored = dataset.rename(columns={'fixed acidity': 'fixed_acidity',
                             'volatile acidity': 'volatile_acidity',
                             'citric acid': 'citric_acid',
                             'residual sugar': 'residual_sugar',
                             'free sulfur dioxide': 'free_sulfur_dioxide',
                             'total sulfur dioxide': 'total_sulfur_dioxide'
                            })
dataset_underscored.head()
# Out:
#    fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free_sulfur_dioxide  total_sulfur_dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %% [markdown]
# And here's a slightly better way you could do it. You can avoid making naming errors due to typos caused by manual typing. However, this looks a little repetitive. Can you make it better?

# %%
labels = list(dataset.columns)
for index in range(len(labels)): labels[index] = labels[index].replace(' ', '_')
dataset.columns = labels
dataset.head()
# Out:
#    fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free_sulfur_dioxide  total_sulfur_dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %% [markdown]
# ### Analyzing Features
# Now that your columns are ready, you want to see how different features of this dataset relate to the quality rating of the wine. A very simple way you could do this is by observing the mean quality rating for the top and bottom half of each feature. The code below does this for four features. It looks pretty repetitive right now. Can you make this more concise?
#
# You might challenge yourself to figure out how to make this code more efficient! But you don't need to worry too much about efficiency right now - we will cover that more in the next section.

# %%
median_alcohol = dataset.alcohol.median()
for i, alcohol in enumerate(dataset.alcohol):
    if alcohol >= median_alcohol:
        dataset.loc[i, 'alcohol'] = 'high'
    else:
        dataset.loc[i, 'alcohol'] = 'low'
dataset.groupby('alcohol').quality.mean()
# Out:
# alcohol
# high    5.958904
# low     5.310302
# Name: quality, dtype: float64

# %%
median_pH = dataset.pH.median()
for i, pH in enumerate(dataset.pH):
    if pH >= median_pH:
        dataset.loc[i, 'pH'] = 'high'
    else:
       dataset.loc[i, 'pH'] = 'low'
dataset.groupby('pH').quality.mean()
# Out:
# pH
# high    5.598039
# low     5.675607
# Name: quality, dtype: float64

# %%
median_sugar = dataset.residual_sugar.median()
for i, sugar in enumerate(dataset.residual_sugar):
    if sugar >= median_sugar:
        dataset.loc[i, 'residual_sugar'] = 'high'
    else:
        dataset.loc[i, 'residual_sugar'] = 'low'
dataset.groupby('residual_sugar').quality.mean()
# Out:
# residual_sugar
# high    5.665880
# low     5.602394
# Name: quality, dtype: float64

# %%
median_citric_acid = dataset.citric_acid.median()
for i, citric_acid in enumerate(dataset.citric_acid):
    if citric_acid >= median_citric_acid:
        dataset.loc[i, 'citric_acid'] = 'high'
    else:
        dataset.loc[i, 'citric_acid'] = 'low'
dataset.groupby('citric_acid').quality.mean()
# Out:
# citric_acid
# high    5.822360
# low     5.447103
# Name: quality, dtype: float64

# %%
def calculate_features(dataset, column_name):
    median = dataset[column_name].median()

    for i, value in enumerate(dataset[column_name]):
        if value >= median:
            dataset.loc[i, column_name] = 'high'
        else:
            dataset.loc[i, column_name] = 'low'
    dataset.groupby(column_name).quality.mean()

# calculate_features('citric_acid')

for feature in dataset.columns[:-1]:
    calculate_features(dataset, feature)
    print(dataset.groupby(feature).quality.mean(), '\n')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~/.local/lib/python3.8/site-packages/pandas/core/nanops.py in nanmedian(values, axis, skipna, mask)
#     718         try:
# --> 719             values = values.astype("f8")
#     720         except ValueError as err:
#
# ValueError: could not convert string to float: 'low'
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_67317/2997388438.py in <module>
#      12
#      13 for feature in dataset.columns[:-1]:
# ---> 14     calculate_features(dataset, feature)
#      15     print(dataset.groupby(feature).quality.mean(), '\n')
#
# /tmp/ipykernel_67317/2997388438.py in calculate_features(dataset, column_name)
#       1 def calculate_features(dataset, column_name):
# ...
